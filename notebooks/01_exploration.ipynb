# %%
import pandas as pd
import os

# %%
path = r"C:\Users\arnaw\OneDrive\Desktop\transfer_recomender\data\players_data-2024_2025.csv.csv"
print("File exists:", os.path.exists(path))
# Out:
# File exists: True

# %%
df = pd.read_csv(path)
print(df.shape)
df.head()
# Out:
# (2854, 267)
#    Rk             Player   Nation    Pos        Squad                Comp  \
# 0   1         Max Aarons  eng ENG     DF  Bournemouth  eng Premier League
# 1   2         Max Aarons  eng ENG  DF,MF     Valencia          es La Liga
# 2   3     Rodrigo Abajas   es ESP     DF     Valencia          es La Liga
# 3   4     James Abankwah   ie IRL  DF,MF      Udinese          it Serie A
# 4   5  Keyliane Abdallah   fr FRA     FW    Marseille          fr Ligue 1
#
#     Age    Born  MP  Starts  ...  Att (GK)  Thr  Launch%  AvgLen  Opp  Stp  \
# 0  24.0  2000.0   3       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 1  24.0  2000.0   4       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 2  21.0  2003.0   1       1  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 3  20.0  2004.0   6       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
# 4  18.0  2006.0   1       0  ...       NaN  NaN      NaN     NaN  NaN  NaN
#
#    Stp%  #OPA  #OPA/90  AvgDist
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2854 entries, 0 to 2853
# Columns: 267 entries, Rk to AvgDist
# dtypes: float64(111), int64(121), object(35)
# memory usage: 5.8+ MB

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# CS%                      2651
# PSxG/SoT                 2648
# Save%                    2648
# AvgDist                  2646
# Cmp%_stats_keeper_adv    2644
# Stp%                     2643
# MP_stats_keeper          2642
# Starts_stats_keeper      2642
# Min_stats_keeper         2642
# 90s_stats_keeper         2642
# GA                       2642
# GA90                     2642
# SoTA                     2642
# Saves                    2642
# W                        2642
# PKA                      2642
# PKA_stats_keeper_adv     2642
# PKsv                     2642
# PKm                      2642
# Rk_stats_keeper_adv      2642
# dtype: int64

# %%
print("Leagues:", df['Comp'].unique())
print("Positions:", df['Pos'].unique())
print("Total players:", len(df))
# Out:
# Leagues: ['eng Premier League' 'es La Liga' 'it Serie A' 'fr Ligue 1'
#  'de Bundesliga']
# Positions: ['DF' 'DF,MF' 'FW' 'MF,FW' 'MF' 'FW,MF' 'GK' 'FW,DF' 'DF,FW' 'MF,DF']
# Total players: 2854
